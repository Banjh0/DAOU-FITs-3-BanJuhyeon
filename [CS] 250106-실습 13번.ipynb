# %%
# 배열의 요소 추가/삽입
arr = [1, 2, 3]

# %%
arr.append(4)
arr
# Out:
# [1, 2, 3, 4]

# %%
arr[3]
# Out:
# 4

# %%
arr.insert(1, 10)
arr
# Out:
# [1, 10, 2, 3, 4]

# %%
arr[1]
# Out:
# 10

# %%
arr_ones = [1] * 5
arr
# Out:
# [1, 10, 2, 3, 4]

# %%
# 배열 요소 수정
arr = [1, 2, 3, 4, 5]

# %%
arr[2]
# Out:
# 3

# %%
arr[2] = 99

# %%
arr[2]
# Out:
# 99

# %%
# 배열 요소 삭제
arr = [10, 20, 30, 40, 50]

# %%
arr.remove(30)

# %%
arr.pop()
# Out:
# 50

# %%
arr.pop(0)
# Out:
# 10

# %%
# 배열 합치기
arr1 = [1, 2, 3]
arr2 = [4, 5, 6]
arr3 = arr1 + arr2
arr3
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
arr1.extend(arr2)
arr1
# Out:
# [1, 2, 3, 4, 5, 6]
